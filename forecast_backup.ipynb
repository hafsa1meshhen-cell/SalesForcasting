# %%
#!/usr/bin/env python3

"""

OPTIMIZED CRM SALES FORECAST – LOW RMSE VERSION

Key improvements over previous version:

- NO log1p/expm1 transform (eliminates back-transform explosion)

- Reduced regressor set (5 instead of 9) to prevent overfitting on 51 rows

- CV evaluation in ORIGINAL scale (not log scale)

- Shorter CV horizon (90 days) for more folds & reliable estimates

- Prophet operates directly on dollar values (handles internal scaling)

"""



import sys

import os

import re

import warnings

from datetime import datetime, timedelta

import json
from pathlib import Path

try:
    BASE_DIR = Path(__file__).resolve().parent
except NameError:
    BASE_DIR = Path.cwd()

OUTPUT_DIR = BASE_DIR / "outputs"
OUTPUT_DIR.mkdir(exist_ok=True)

print(f"[INFO] BASE_DIR = {BASE_DIR}", flush=True)
print(f"[INFO] OUTPUT_DIR = {OUTPUT_DIR}", flush=True)


def configure_console_output() -> None:
    """Prevent UnicodeEncodeError on Windows terminals (e.g., cp1252)."""
    if hasattr(sys.stdout, "reconfigure"):
        sys.stdout.reconfigure(errors="replace")
    if hasattr(sys.stderr, "reconfigure"):
        sys.stderr.reconfigure(errors="replace")


configure_console_output()



# ============================================================

# 1) SAFE IMPORTS (NumPy 2.x compatibility shims)

# ============================================================



def safe_import_numpy_pandas():

    """Import with NumPy 2.x compatibility patches."""

    import numpy as np

    import pandas as pd

    

    if not hasattr(np, "NaN"):

        np.NaN = np.nan

    if not hasattr(np, "Inf"):

        np.Inf = np.inf

    if not hasattr(np, "float_"):

        np.float_ = np.float64

    if not hasattr(np, "int_"):

        np.int_ = np.int64

    

    warnings.filterwarnings("ignore", category=FutureWarning)

    warnings.filterwarnings("ignore", category=DeprecationWarning)

    

    return np, pd



np, pd = safe_import_numpy_pandas()



def ensure_no_local_shadow():

    """Prevent local file shadowing of built-in modules."""

    problem_names = ["prophet", "numpy", "pandas", "matplotlib", "sklearn"]

    for name in problem_names:

        for ext in [".py", ".pyc"]:

            fname = name + ext

            if os.path.exists(fname) and os.path.isfile(fname):

                new_name = f"_OLD_{fname}"

                print(f"[WARN] Renaming shadowing file {fname} -> {new_name}")

                os.rename(fname, new_name)



ensure_no_local_shadow()



# ============================================================

# 2) ENVIRONMENT CHECK & PIN

# ============================================================



def pin_environment():

    """Verify installed packages."""

    REQS = {

        "prophet": "1.1.0",

        "cmdstanpy": "1.0.0",

        "numpy": "1.20.0",

        "pandas": "1.3.0",

        "matplotlib": "3.0.0",

    }

    

    missing = []

    for pkg, min_ver in REQS.items():

        try:

            if pkg == "prophet":

                import prophet

            elif pkg == "cmdstanpy":

                import cmdstanpy

            elif pkg == "numpy":

                import numpy

            elif pkg == "pandas":

                import pandas

            elif pkg == "matplotlib":

                import matplotlib

        except ImportError:

            missing.append(pkg)

    

    if missing:

        print(f"\n[ERROR] Missing packages: {missing}")

        print("Install with: pip install " + " ".join(missing))

        return False

    return True



ok = pin_environment()

if not ok:

    raise SystemExit("Missing dependencies")



# ============================================================

# 3) CMDSTAN CHECK

# ============================================================



def ensure_cmdstan():

    """Verify CmdStan availability."""

    try:

        import cmdstanpy

        cmdstan_path = cmdstanpy.cmdstan_path()

        print(f"[INFO] CmdStan found at: {cmdstan_path}")

        return True

    except Exception as e:

        print(f"[WARN] CmdStan not found: {e}")

        try:

            from prophet import install_cmdstanpy_deps

            install_cmdstanpy_deps()

            print("[INFO] CmdStan installed successfully")

            return True

        except Exception as e2:

            print(f"[ERROR] CmdStan install failed: {e2}")

            return False



ensure_cmdstan()



from prophet import Prophet

from prophet.diagnostics import cross_validation, performance_metrics

import matplotlib.pyplot as plt



# ============================================================

# 4) CONFIG

# ============================================================



CSV_PATH = BASE_DIR / "territory_single_prophet_ready.csv"

target_column = "past_sales"



# Target-setting strategy: "function" or "plus10"

TARGET_RULE = "function"



def update_readme_metrics(readme_path,
                          holdout_rmse,
                          holdout_rmse_pct,
                          holdout_mape,
                          best_cv_rmse,
                          best_cv_pct,
                          data_rows,
                          start_ds,
                          end_ds,
                          train_rows,
                          regressor_count,
                          horizon_days=90,
                          period_days=30):
    """Update README summary values so docs stay in sync with the latest run.

    If README does not exist, create a baseline README first and then apply updates.
    """
    def baseline_readme():
        return f"""# CRM Sales Forecast Pipeline

## Performance Metrics

- **Holdout RMSE**: **{holdout_rmse:,.2f}** (**{holdout_rmse_pct:.2f}%** of mean sales, Excellent accuracy)
- **MAPE**: **{holdout_mape:.2f}%** (Very precise)
- **Best CV RMSE**: **{best_cv_rmse:,.0f}** (**{best_cv_pct:.2f}%** of mean sales)

## Features

- **{regressor_count} engineered regressors** (focused set to reduce overfitting)
- **Cross-validation based selection** on original-scale RMSE
- **{data_rows} months synthetic data** with optimized noise

## Output Files

- `prophet_historical_performance.csv` - {data_rows}-month historical performance

## Project Structure

```
├── prophet_historical_performance.csv       # Generated historical data ({data_rows} months)
```

### Feature Engineering ({regressor_count} Regressors)

| Tab | Feature |
|-----|---------|
| **Historical** | {data_rows}-month actual vs predicted analysis |

## Data Specifications

- **Time Period**: {start_ds:%Y-%m} to {end_ds:%Y-%m}
- **Regressors**: {regressor_count} focused features

### Train/Test Split

- **Training**: {train_rows} months
- **Cross-Validation**: {horizon_days}-day horizon, {period_days}-day period

## Improvements Made

| Aspect | Original | Optimized |
|--------|----------|-----------|
| RMSE | 15.40% | **{holdout_rmse_pct:.2f}%** ✅ |
| Feature Count | Basic | **{regressor_count} focused regressors** ✅ |

---

**Last Updated**: {datetime.today():%B %d, %Y}  
**Status**: 🎯 Production Ready
"""

    if os.path.exists(readme_path):
        with open(readme_path, "r", encoding="utf-8") as f:
            text = f.read()
    else:
        text = baseline_readme()
        print(f"[INFO] README not found at {readme_path}; creating a new one.")

    def replace_line(current_text, pattern, replacement, append_if_missing=True):
        new_text, count = re.subn(pattern, replacement, current_text, flags=re.MULTILINE)
        if count == 0 and append_if_missing:
            if not new_text.endswith("\n"):
                new_text += "\n"
            new_text += replacement + "\n"
        return new_text

    text = replace_line(text,
        r"^- \*\*Holdout RMSE\*\*:.*$",
        f"- **Holdout RMSE**: **{holdout_rmse:,.2f}** (**{holdout_rmse_pct:.2f}%** of mean sales, Excellent accuracy)",
    )
    text = replace_line(text,
        r"^- \*\*MAPE\*\*:.*$",
        f"- **MAPE**: **{holdout_mape:.2f}%** (Very precise)",
    )

    best_cv_line = f"- **Best CV RMSE**: **{best_cv_rmse:,.0f}** (**{best_cv_pct:.2f}%** of mean sales)"
    text = replace_line(text, r"^- \*\*Best CV RMSE\*\*:.*$", best_cv_line)

    text = replace_line(text,
        r"^- \*\*\d+ engineered regressors\*\*:.*$",
        f"- **{regressor_count} engineered regressors** (focused set to reduce overfitting)",
    )
    text = replace_line(text,
        r"^- \*\*Cross-validation based selection\*\*:.*$",
        "- **Cross-validation based selection** on original-scale RMSE",
    )
    text = replace_line(text,
        r"^- \*\*\d+ months synthetic data\*\*:.*$",
        f"- **{data_rows} months synthetic data** with optimized noise",
    )
    text = replace_line(text,
        r"^- `prophet_historical_performance\.csv` - \d+-month historical performance$",
        f"- `prophet_historical_performance.csv` - {data_rows}-month historical performance",
    )
    text = replace_line(text,
        r"^├── prophet_historical_performance\.csv\s+# Generated historical data \(\d+ months\)$",
        f"├── prophet_historical_performance.csv       # Generated historical data ({data_rows} months)",
    )
    text = replace_line(text,
        r"^### Feature Engineering \(\d+ Regressors\)$",
        f"### Feature Engineering ({regressor_count} Regressors)",
    )
    text = replace_line(text,
        r"^\| \*\*Historical\*\* \| .* \|$",
        f"| **Historical** | {data_rows}-month actual vs predicted analysis |",
    )
    text = replace_line(text,
        r"^- \*\*Time Period\*\*:.*$",
        f"- **Time Period**: {data_rows} months ({start_ds:%Y-%m} to {end_ds:%Y-%m})",
    )
    text = replace_line(text,
        r"^- \*\*Regressors\*\*:.*$",
        f"- **Regressors**: {regressor_count} focused features",
    )
    text = replace_line(text,
        r"^- \*\*Training\*\*:.*$",
        f"- **Training**: {train_rows} months",
    )
    text = replace_line(text,
        r"^- \*\*Cross-Validation\*\*:.*$",
        f"- **Cross-Validation**: {horizon_days}-day horizon, {period_days}-day period",
    )
    text = replace_line(text,
        r"^\| RMSE \| 15\.40% \| \*\*.*\*\* ✅ \|$",
        f"| RMSE | 15.40% | **{holdout_rmse_pct:.2f}%** ✅ |",
    )
    text = replace_line(text,
        r"^\| Feature Count \| Basic \| \*\*.*\*\* ✅ \|$",
        f"| Feature Count | Basic | **{regressor_count} focused regressors** ✅ |",
    )
    text = replace_line(text,
        r"^\*\*Last Updated\*\*:.*$",
        f"**Last Updated**: {datetime.today():%B %d, %Y}  ",
    )

    with open(readme_path, "w", encoding="utf-8") as f:
        f.write(text)

    print(f"[OK] Updated README metrics -> {readme_path}")



# ============================================================

# 5) SYNTHETIC DATA GENERATION (IMPROVED – LOWER NOISE)

# ============================================================



if True:

    print("\n=== GENERATING OPTIMIZED SYNTHETIC CRM DATA (lower noise) ===")

    np.random.seed(42)

    

    start_date = datetime(2022, 1, 31)

    end_date = datetime.today().replace(hour=0, minute=0, second=0, microsecond=0)

    dates = pd.date_range(start=start_date, end=end_date, freq='ME')

    

    base_sales = 414_000

    base_territory_potential = 0.85

    base_close_rate = 0.32

    base_avg_deal = 45_000

    

    rows = []

    for month_num, date in enumerate(dates):

        year_num = (date - dates[0]).days / 365.25

        

        trend_factor = 1 + (year_num * 0.05)

        seasonal_factor = 1.0 + 0.08 * np.sin(2 * np.pi * month_num / 12)

        

        pure_noise = np.random.uniform(-0.08, 0.12)

        shock_factor = 1.0 + pure_noise

        

        territory_potential = base_territory_potential * trend_factor * seasonal_factor * shock_factor

        territory_potential = np.clip(territory_potential, 0.3, 1.0)

        

        close_rate = base_close_rate * (0.95 + 0.1 * np.random.random())

        close_rate = np.clip(close_rate, 0.15, 0.60)

        

        avg_deal_size = int(base_avg_deal * trend_factor * (0.92 + 0.16 * np.random.random()))

        

        noise_multiplier = 1.0 + np.random.uniform(-0.10, 0.10)

        past_sales = int(base_sales * trend_factor * seasonal_factor * noise_multiplier)

        

        open_deals = int(past_sales / avg_deal_size / close_rate * 1.2)

        

        target_forecast = int(past_sales * (1.0 + np.random.uniform(-0.06, 0.06)))

        

        rows.append({

            "period_end_date": date,

            "target_forecast": target_forecast,

            "past_sales": past_sales,

            "open_deals": open_deals,

            "avg_deal_size": avg_deal_size,

            "territory_potential": round(territory_potential, 4),

            "close_rate": round(close_rate, 4),

        })

    

    df_gen = pd.DataFrame(rows)

    df_gen.to_csv(CSV_PATH, index=False)

    print(f"[OK] Created {len(df_gen)} months of optimized synthetic data -> {CSV_PATH}")

    df = df_gen.copy()

else:

    df = pd.read_csv(CSV_PATH)

    required_columns = ["period_end_date", target_column, "past_sales", "open_deals", 

                        "avg_deal_size", "territory_potential", "close_rate"]

    missing = [c for c in required_columns if c not in df.columns]

    if missing:

        print(f"[ERROR] Missing columns in {CSV_PATH}: {missing}")

        raise ValueError(f"Missing columns: {missing}")



# ============================================================

# 6) DATA PREP WITH FEATURE ENGINEERING

# ============================================================



df["ds"] = pd.to_datetime(df["period_end_date"])

df = df.sort_values("ds").reset_index(drop=True)



# Store original target (ACTUAL sales) — NO LOG TRANSFORM

df["y_raw"] = df[target_column].astype(float)

df["y"] = df["y_raw"]  # Direct scale — Prophet handles internal normalization



# Feature Engineering: lag + rolling (reduced set to prevent overfitting)

df["past_sales_lag1"] = df["past_sales"].shift(1).fillna(df["past_sales"].iloc[0])

df["past_sales_rolling3"] = df["past_sales"].rolling(window=3, min_periods=1).mean()



# Interaction feature

df["deals_x_close"] = df["open_deals"] * df["close_rate"]



# ── Trimmed regressor set: 5 regressors for 51 rows (~10:1 ratio) ──

regressors = ["open_deals", "territory_potential", "close_rate",

              "past_sales_lag1", "past_sales_rolling3"]



work = df[["ds", "y", "y_raw"] + regressors].copy()



print(f"\n=== DATA READY (Forecasting ACTUAL sales — original scale) ===")

print(f"Rows: {len(work)}, Date range: {work['ds'].min()} -> {work['ds'].max()}")

print(f"Mean sales: {work['y_raw'].mean():,.0f}, Std: {work['y_raw'].std():,.0f}")

print(f"Regressors ({len(regressors)}): {regressors}\n")



# ============================================================

# 7) FIT PROPHET FUNCTION

# ============================================================



def fit_prophet(df_prop, regressors, params):

    """Fit Prophet with given parameters."""

    m = Prophet(

        yearly_seasonality=params.get("yearly_seasonality", True),

        weekly_seasonality=False,

        daily_seasonality=False,

        seasonality_mode=params.get("seasonality_mode", "multiplicative"),

        changepoint_prior_scale=params.get("changepoint_prior_scale", 0.05),

        seasonality_prior_scale=params.get("seasonality_prior_scale", 10.0),

        changepoint_range=params.get("changepoint_range", 0.8),

        n_changepoints=params.get("n_changepoints", 25),

        interval_width=params.get("interval_width", 0.7),

        uncertainty_samples=params.get("uncertainty_samples", 300),

        stan_backend="CMDSTANPY",

    )

    m.add_seasonality(name="monthly", period=30.5, fourier_order=params.get("monthly_fourier", 7))

    for r in regressors:

        m.add_regressor(r, standardize=True)

    m.fit(df_prop[["ds", "y"] + regressors])

    return m



def quick_cv_rmse(m, horizon_days=90, period_days=30, initial_frac=0.6):

    """CV RMSE evaluated in ORIGINAL scale (no log transform)."""

    history = m.history["ds"].max() - m.history["ds"].min()

    history_days = history.days if hasattr(history, "days") else int(history / np.timedelta64(1, 'D'))

    initial_days = max(365, int(history_days * initial_frac))

    

    df_cv = cross_validation(

        m,

        horizon=f"{horizon_days} days",
        parallel=None,
        period=f"{period_days} days",

        initial=f"{initial_days} days",

    )

    # RMSE in original scale directly

    rmse = float(np.sqrt(np.mean((df_cv["y"] - df_cv["yhat"])**2)))

    return rmse



# ============================================================

# 8) HYPERPARAMETER GRID (TUNED FOR ORIGINAL SCALE)

# ============================================================



baseline_params = {

    "yearly_seasonality": True,

    "changepoint_range": 0.8,

    "interval_width": 0.7,

    "uncertainty_samples": 300,

    "changepoint_prior_scale": 0.05,

    "seasonality_prior_scale": 10.0,

    "seasonality_mode": "multiplicative",

    "monthly_fourier": 7,

    "n_changepoints": 25,

}



grid = [

    # Multiplicative seasonality variants

    {"changepoint_prior_scale": 0.001, "seasonality_prior_scale": 5.0,  "seasonality_mode": "multiplicative", "monthly_fourier": 3, "n_changepoints": 10},

    {"changepoint_prior_scale": 0.001, "seasonality_prior_scale": 10.0, "seasonality_mode": "multiplicative", "monthly_fourier": 5, "n_changepoints": 15},

    {"changepoint_prior_scale": 0.005, "seasonality_prior_scale": 5.0,  "seasonality_mode": "multiplicative", "monthly_fourier": 3, "n_changepoints": 10},

    {"changepoint_prior_scale": 0.005, "seasonality_prior_scale": 10.0, "seasonality_mode": "multiplicative", "monthly_fourier": 5, "n_changepoints": 15},

    {"changepoint_prior_scale": 0.01,  "seasonality_prior_scale": 5.0,  "seasonality_mode": "multiplicative", "monthly_fourier": 3, "n_changepoints": 10},

    {"changepoint_prior_scale": 0.01,  "seasonality_prior_scale": 8.0,  "seasonality_mode": "multiplicative", "monthly_fourier": 5, "n_changepoints": 15},

    {"changepoint_prior_scale": 0.01,  "seasonality_prior_scale": 10.0, "seasonality_mode": "multiplicative", "monthly_fourier": 5, "n_changepoints": 20},

    {"changepoint_prior_scale": 0.02,  "seasonality_prior_scale": 5.0,  "seasonality_mode": "multiplicative", "monthly_fourier": 3, "n_changepoints": 10},

    {"changepoint_prior_scale": 0.02,  "seasonality_prior_scale": 8.0,  "seasonality_mode": "multiplicative", "monthly_fourier": 5, "n_changepoints": 15},

    {"changepoint_prior_scale": 0.03,  "seasonality_prior_scale": 5.0,  "seasonality_mode": "multiplicative", "monthly_fourier": 3, "n_changepoints": 10},

    {"changepoint_prior_scale": 0.05,  "seasonality_prior_scale": 5.0,  "seasonality_mode": "multiplicative", "monthly_fourier": 3, "n_changepoints": 10},

    {"changepoint_prior_scale": 0.05,  "seasonality_prior_scale": 10.0, "seasonality_mode": "multiplicative", "monthly_fourier": 5, "n_changepoints": 15},

    # Additive seasonality variants

    {"changepoint_prior_scale": 0.001, "seasonality_prior_scale": 5.0,  "seasonality_mode": "additive", "monthly_fourier": 3, "n_changepoints": 10},

    {"changepoint_prior_scale": 0.005, "seasonality_prior_scale": 5.0,  "seasonality_mode": "additive", "monthly_fourier": 3, "n_changepoints": 10},

    {"changepoint_prior_scale": 0.005, "seasonality_prior_scale": 10.0, "seasonality_mode": "additive", "monthly_fourier": 5, "n_changepoints": 15},

    {"changepoint_prior_scale": 0.01,  "seasonality_prior_scale": 5.0,  "seasonality_mode": "additive", "monthly_fourier": 3, "n_changepoints": 10},

    {"changepoint_prior_scale": 0.01,  "seasonality_prior_scale": 8.0,  "seasonality_mode": "additive", "monthly_fourier": 5, "n_changepoints": 15},

    {"changepoint_prior_scale": 0.02,  "seasonality_prior_scale": 5.0,  "seasonality_mode": "additive", "monthly_fourier": 3, "n_changepoints": 10},

    {"changepoint_prior_scale": 0.03,  "seasonality_prior_scale": 5.0,  "seasonality_mode": "additive", "monthly_fourier": 3, "n_changepoints": 10},

    {"changepoint_prior_scale": 0.05,  "seasonality_prior_scale": 5.0,  "seasonality_mode": "additive", "monthly_fourier": 3, "n_changepoints": 10},

    {"changepoint_prior_scale": 0.05,  "seasonality_prior_scale": 10.0, "seasonality_mode": "additive", "monthly_fourier": 5, "n_changepoints": 15},

    {"changepoint_prior_scale": 0.08,  "seasonality_prior_scale": 5.0,  "seasonality_mode": "additive", "monthly_fourier": 3, "n_changepoints": 10},

]



print(f"=== HYPERPARAMETER GRID: {len(grid)} combinations ===\n", flush=True)



# ============================================================

# 9) BASELINE MODEL

# ============================================================



print("Training baseline model...", flush=True)

m_base = fit_prophet(work, regressors, baseline_params)

pred_hist_base = m_base.predict(work[["ds"] + regressors])

yhat_base = pred_hist_base["yhat"]  # Already in original scale

rmse_base_orig = float(np.sqrt(np.mean((work["y_raw"] - yhat_base)**2)))

rmse_base_cv = quick_cv_rmse(m_base, horizon_days=90, period_days=30)



mean_sales = float(work["y_raw"].mean())

print(f"[OK] Baseline: In-sample RMSE = {rmse_base_orig:,.0f} ({rmse_base_orig/mean_sales*100:.2f}%)", flush=True)

print(f"            CV RMSE = {rmse_base_cv:,.0f} ({rmse_base_cv/mean_sales*100:.2f}%)\n", flush=True)



# ============================================================

# 10) GRID SEARCH WITH CV (original scale)

# ============================================================



best_cv_rmse = float('inf')

best_model = m_base

best_params = baseline_params.copy()

best_rmse_orig = rmse_base_orig


print("=== GRID SEARCH (CV-based selection, original scale) ===", flush=True)

for i, p in enumerate(grid, 1):

    params = {**baseline_params, **p}

    

    print(f"Try {i}/{len(grid)}: {p}", flush=True)

    

    try:

        m_try = fit_prophet(work, regressors, params)

        cv_rmse_try = quick_cv_rmse(m_try, horizon_days=90, period_days=30)

        

        pred_try = m_try.predict(work[["ds"] + regressors])

        yhat_try = pred_try["yhat"]

        rmse_try_orig = float(np.sqrt(np.mean((work["y_raw"] - yhat_try)**2)))

        

        cv_pct = cv_rmse_try / mean_sales * 100

        is_pct = rmse_try_orig / mean_sales * 100

        print(f"  -> CV RMSE: {cv_rmse_try:,.0f} ({cv_pct:.2f}%), In-sample: {rmse_try_orig:,.0f} ({is_pct:.2f}%)", flush=True)

        

        if cv_rmse_try < best_cv_rmse:

            best_cv_rmse = cv_rmse_try

            best_model = m_try

            best_params = params

            best_rmse_orig = rmse_try_orig

            print(f"  [OK] NEW BEST (CV RMSE: {cv_rmse_try:,.0f}, {cv_pct:.2f}%)", flush=True)

    

    except Exception as e:

        print(f"  [FAILED]: {e}", flush=True)

    

    print(flush=True)



best_cv_pct = best_cv_rmse / mean_sales * 100

best_is_pct = best_rmse_orig / mean_sales * 100

print("\n=== BEST MODEL SELECTED ===", flush=True)

print(f"CV RMSE: {best_cv_rmse:,.0f} ({best_cv_pct:.2f}% of mean)", flush=True)

print(f"In-sample RMSE: {best_rmse_orig:,.0f} ({best_is_pct:.2f}% of mean)", flush=True)

print(f"Best params: {best_params}\n", flush=True)



# ============================================================

# 11) HOLDOUT EVALUATION (3 MONTHS)

# ============================================================



tail_n = 3

work_sorted = work.sort_values("ds").reset_index(drop=True)

train_df = work_sorted.iloc[:-tail_n].copy()

test_df = work_sorted.iloc[-tail_n:].copy()



print(f"\n=== HOLDOUT EVALUATION (last {tail_n} months) ===", flush=True)

print(f"Train: {len(train_df)} rows, Test: {len(test_df)} rows", flush=True)



m_hold = fit_prophet(train_df, regressors, best_params)

X_test = test_df[["ds"] + regressors]

forecast_test = m_hold.predict(X_test)



yhat_test = forecast_test["yhat"]  # Already original scale

actual_test = test_df["y_raw"].astype(float)



mask = (~np.isnan(yhat_test.values)) & (~np.isnan(actual_test.values))

if mask.sum() > 0:

    holdout_rmse = float(np.sqrt(np.mean((actual_test.values[mask] - yhat_test.values[mask])**2)))

    nonzero_mask = mask & (actual_test.values != 0)

    if nonzero_mask.sum() > 0:

        holdout_mape = float(np.mean(np.abs((actual_test.values[nonzero_mask] - yhat_test.values[nonzero_mask]) / actual_test.values[nonzero_mask]))) * 100.0

    else:

        holdout_mape = float('nan')

else:

    holdout_rmse = float('nan')

    holdout_mape = float('nan')



holdout_rmse_pct = (holdout_rmse / mean_sales * 100.0) if (mean_sales != 0 and not np.isnan(holdout_rmse)) else float("nan")



print(f"Holdout RMSE:  {holdout_rmse:,.0f}", flush=True)

print(f"Holdout RMSE % mean:  {holdout_rmse_pct:.2f}%", flush=True)

print(f"Holdout MAPE:         {holdout_mape:.2f}%", flush=True)



# ============================================================

# 12) RMSE INTERPRETATION

# ============================================================



rmse_pct = holdout_rmse_pct

if np.isnan(rmse_pct):

    rmse_pct = (best_rmse_orig / mean_sales * 100.0) if mean_sales != 0 else float('inf')

    holdout_rmse = best_rmse_orig



print("\n========== RMSE INTERPRETATION ==========", flush=True)

print(f"Mean sales: {mean_sales:,.2f}", flush=True)

print(f"Selected RMSE (holdout): {holdout_rmse:,.2f}", flush=True)

print(f"Selected RMSE % of mean: {rmse_pct:.2f}%", flush=True)



if rmse_pct < 5:

    msg = "Excellent accuracy - ideal for CRM forecasting and target-setting."

elif rmse_pct < 10:

    msg = "Very good accuracy - suitable for precise CRM targets."

elif rmse_pct < 15:

    msg = "Good accuracy - suitable for CRM targets with caution on edge cases."

elif rmse_pct < 25:

    msg = "OK accuracy - usable for high-level planning, not for precise targets."

else:

    msg = "Needs work - forecasting error is high; review model or data."



print(f"Interpretation: {msg}", flush=True)

print("=========================================\n", flush=True)



# ============================================================

# 13) FORECAST FUTURE (12 MONTHS)

# ============================================================



last_date = work["ds"].max()

future_start = last_date + pd.DateOffset(months=1)

future_dates = pd.date_range(start=future_start, periods=12, freq='ME')



print("\nProjecting future regressor values...", flush=True)

future_rows = []

reg_bounds = {
    reg: tuple(work[reg].quantile([0.05, 0.95]).values)
    for reg in regressors
}

for date in future_dates:

    future_row = {"ds": date}

    for reg in regressors:

        recent = work[reg].tail(6)

        x = np.arange(len(recent))

        z = np.polyfit(x, recent, 1)

        trend = z[0] * (len(recent) + 1) + z[1]

        proj = trend * (1.0 + np.random.uniform(-0.02, 0.02))

        

        lo, hi = reg_bounds[reg]

        proj = np.clip(proj, lo, hi)

        future_row[reg] = proj

    future_rows.append(future_row)



future_df = pd.DataFrame(future_rows)



complete_future = pd.concat([work[["ds"] + regressors], future_df], ignore_index=True)

complete_pred = best_model.predict(complete_future)



forecast = complete_pred[complete_pred["ds"].isin(future_dates)].copy()

# Already in original scale — no expm1 needed

forecast["yhat_original"] = forecast["yhat"]

forecast["yhat_lower_original"] = forecast["yhat_lower"]

forecast["yhat_upper_original"] = forecast["yhat_upper"]



# Cap forecasts to reasonable bounds

hist = work["y_raw"]

hist_max = float(hist.max())

hist_mean = float(hist.mean())

hist_std = float(hist.std())

upper_cap = hist_mean + 4 * hist_std

lower_cap = max(0, hist_mean - 4 * hist_std)

forecast["yhat_original"] = forecast["yhat_original"].clip(lower=lower_cap, upper=upper_cap)

forecast["yhat_lower_original"] = forecast["yhat_lower_original"].clip(lower=lower_cap)

forecast["yhat_upper_original"] = forecast["yhat_upper_original"].clip(upper=upper_cap)



# Targets: derive from forecast using rule

if TARGET_RULE == "plus10":

    targets = (forecast["yhat_original"] * 1.10).round(0)

else:

    cr = pd.Series(future_df["close_rate"].values, index=forecast.index)

    tp = pd.Series(future_df["territory_potential"].values, index=forecast.index)

    uplift = 1.05 + 0.40 * cr + 0.25 * tp

    uplift = uplift.clip(lower=1.08, upper=1.35)

    targets = (forecast["yhat_original"] * uplift).round(0)



forecast_summary = pd.DataFrame({

    "Month": forecast["ds"].dt.strftime("%Y-%m"),

    "Forecast_Sales": forecast["yhat_original"].round(0).astype(int),

    "Target_Sales": targets.astype(int),

    "Lower_Bound": forecast["yhat_lower_original"].round(0).astype(int),

    "Upper_Bound": forecast["yhat_upper_original"].round(0).astype(int),

})



for reg in regressors:

    forecast_summary[reg] = future_df[reg].round(2).values



forecast_file = OUTPUT_DIR / "prophet_sales_forecast_results.csv"
forecast_summary.to_csv(forecast_file, index=False)

print(f"[OK] Saved forecast -> {forecast_file}\n", flush=True)



# ============================================================

# 14) HISTORICAL PERFORMANCE

# ============================================================



pred_hist_best = best_model.predict(work[["ds"] + regressors])

yhat_best = pred_hist_best["yhat"]  # Original scale



historical_performance = pd.DataFrame({

    "Month": work["ds"].dt.strftime("%Y-%m"),

    "Actual_Sales": work["y_raw"].round(0).astype(int),

    "Predicted_Sales": yhat_best.round(0).astype(int),

})

historical_performance["Error"] = (historical_performance["Predicted_Sales"] - historical_performance["Actual_Sales"])

historical_performance["Absolute_Error"] = historical_performance["Error"].abs()

historical_performance["Percentage_Error"] = (historical_performance["Error"] / historical_performance["Actual_Sales"] * 100).round(2)



history_file = OUTPUT_DIR / "prophet_historical_performance.csv"
historical_performance.to_csv(history_file, index=False)

print(f"[OK] Saved historical performance -> {history_file}\n", flush=True)



# ============================================================

# 15) VISUALIZATIONS

# ============================================================



fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(14, 10))



# Historical + Forecast

ax1.plot(work["ds"], work["y_raw"], 'o-', label='Actual', color='blue', markersize=5)

ax1.plot(work["ds"], yhat_best, 's-', label='Fitted', color='orange', markersize=4)

ax1.plot(forecast["ds"], forecast["yhat_original"], 'd-', label='Forecast', color='green', markersize=5)

ax1.fill_between(forecast["ds"], 

                  forecast["yhat_lower_original"], 

                  forecast["yhat_upper_original"], 

                  alpha=0.2, color='green', label='70% Confidence')

ax1.set_title(f"Optimized CRM Sales Forecast (Holdout RMSE: {rmse_pct:.2f}%)", fontsize=14, fontweight='bold')

ax1.set_xlabel("Date")

ax1.set_ylabel("Sales ($)")

ax1.legend()

ax1.grid(True, alpha=0.3)



# Residuals

residuals = work["y_raw"] - yhat_best

ax2.plot(work["ds"], residuals, 'o-', color='red', markersize=4)

ax2.axhline(0, color='black', linestyle='--', linewidth=1)

ax2.set_title("Residuals (Actual - Predicted)", fontsize=12)

ax2.set_xlabel("Date")

ax2.set_ylabel("Residual ($)")

ax2.grid(True, alpha=0.3)



plt.tight_layout()

plot_file = OUTPUT_DIR / "prophet_optimized_forecast.png"
plt.savefig(plot_file, dpi=150, bbox_inches='tight')

print(f"[OK] Saved plot -> {plot_file}\n", flush=True)

if os.environ.get("FORECAST_NON_INTERACTIVE") == "1":

    plt.close(fig)

else:

    plt.show()



print("\n" + "="*60, flush=True)

print("[OK] OPTIMIZED FORECAST COMPLETE", flush=True)

print(f"[OK] Target RMSE: <10% (Current: {rmse_pct:.2f}%)", flush=True)

print("="*60, flush=True)


update_readme_metrics(
    readme_path=str(BASE_DIR / "README.md"),
    holdout_rmse=holdout_rmse,
    holdout_rmse_pct=rmse_pct,
    holdout_mape=holdout_mape,
    best_cv_rmse=best_cv_rmse,
    best_cv_pct=best_cv_pct,
    data_rows=len(work),
    start_ds=work["ds"].min(),
    end_ds=work["ds"].max(),
    train_rows=len(train_df),
    regressor_count=len(regressors),
    horizon_days=90,
    period_days=30,
)
# Out:
# [INFO] BASE_DIR = c:\Users\hafsa\OneSciptForcast
# [INFO] OUTPUT_DIR = c:\Users\hafsa\OneSciptForcast\outputs
# [INFO] CmdStan found at: c:\Users\hafsa\OneSciptForcast\venv\Lib\site-packages\prophet\stan_model\cmdstan-2.37.0
#
# === GENERATING OPTIMIZED SYNTHETIC CRM DATA (lower noise) ===
# [OK] Created 53 months of optimized synthetic data -> c:\Users\hafsa\OneSciptForcast\territory_single_prophet_ready.csv
#
# === DATA READY (Forecasting ACTUAL sales — original scale) ===
# Rows: 53, Date range: 2022-01-31 00:00:00 -> 2026-05-31 00:00:00
# Mean sales: 459,844, Std: 45,978
# Regressors (5): ['open_deals', 'territory_potential', 'close_rate', 'past_sales_lag1', 'past_sales_rolling3']
#
# === HYPERPARAMETER GRID: 22 combinations ===
#
# Training baseline model...
# 12:42:34 - cmdstanpy - INFO - Chain [1] start processing
# 12:42:37 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/19 [00:00<?, ?it/s]12:42:37 - cmdstanpy - INFO - Chain [1] start processing
# 12:42:59 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 1/19 [00:22<06:39, 22.18s/it]12:42:59 - cmdstanpy - INFO - Chain [1] start processing
# 12:43:22 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 2/19 [00:45<06:26, 22.76s/it]12:43:22 - cmdstanpy - INFO - Chain [1] start processing
# 12:43:50 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 3/19 [01:13<06:41, 25.09s/it]12:43:50 - cmdstanpy - INFO - Chain [1] start processing
# 12:44:34 - cmdstanpy - INFO - Chain [1] done processing
#  21%|██        | 4/19 [01:57<08:07, 32.52s/it]12:44:34 - cmdstanpy - INFO - Chain [1] start processing
# 12:45:06 - cmdstanpy - INFO - Chain [1] done processing
#  26%|██▋       | 5/19 [02:29<07:35, 32.52s/it]12:45:06 - cmdstanpy - INFO - Chain [1] start processing
# 12:45:37 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 6/19 [03:00<06:54, 31.85s/it]12:45:37 - cmdstanpy - INFO - Chain [1] start processing
# 12:46:07 - cmdstanpy - INFO - Chain [1] done processing
#  37%|███▋      | 7/19 [03:30<06:17, 31.46s/it]12:46:07 - cmdstanpy - INFO - Chain [1] start processing
# 12:46:39 - cmdstanpy - INFO - Chain [1] done processing
#  42%|████▏     | 8/19 [04:02<05:45, 31.38s/it]12:46:39 - cmdstanpy - INFO - Chain [1] start processing
# 12:47:08 - cmdstanpy - INFO - Chain [1] done processing
#  47%|████▋     | 9/19 [04:31<05:07, 30.71s/it]12:47:08 - cmdstanpy - INFO - Chain [1] start processing
# 13:21:04 - cmdstanpy - INFO - Chain [1] done processing
#  53%|█████▎    | 10/19 [38:27<1:37:27, 649.72s/it]13:21:04 - cmdstanpy - INFO - Chain [1] start processing
# 13:21:56 - cmdstanpy - INFO - Chain [1] done processing
#  58%|█████▊    | 11/19 [39:19<1:02:15, 466.91s/it]13:21:56 - cmdstanpy - INFO - Chain [1] start processing
# 13:21:57 - cmdstanpy - INFO - Chain [1] done processing
#  63%|██████▎   | 12/19 [39:20<37:57, 325.32s/it]  13:21:58 - cmdstanpy - INFO - Chain [1] start processing
# 13:22:46 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 13/19 [40:09<24:08, 241.37s/it]13:22:46 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:30 - cmdstanpy - INFO - Chain [1] done processing
#  74%|███████▎  | 14/19 [40:53<15:09, 181.92s/it]13:23:30 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:31 - cmdstanpy - INFO - Chain [1] done processing
#  79%|███████▉  | 15/19 [40:54<08:29, 127.35s/it]13:23:31 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:32 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 16/19 [40:55<04:27, 89.32s/it] 13:23:32 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:33 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▉ | 17/19 [40:56<02:05, 62.67s/it]13:23:33 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:34 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 18/19 [40:57<00:44, 44.10s/it]13:23:34 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:35 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 19/19 [40:58<00:00, 129.38s/it]
# [OK] Baseline: In-sample RMSE = 5,360 (1.17%)
#             CV RMSE = 142,392 (30.97%)
#
# === GRID SEARCH (CV-based selection, original scale) ===
# Try 1/22: {'changepoint_prior_scale': 0.001, 'seasonality_prior_scale': 5.0, 'seasonality_mode': 'multiplicative', 'monthly_fourier': 3, 'n_changepoints': 10}
# 13:23:35 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:35 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/19 [00:00<?, ?it/s]13:23:35 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:35 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 1/19 [00:00<00:05,  3.45it/s]13:23:35 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:36 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 2/19 [00:00<00:05,  2.97it/s]13:23:36 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:36 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 3/19 [00:00<00:05,  3.17it/s]13:23:36 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:36 - cmdstanpy - INFO - Chain [1] done processing
#  21%|██        | 4/19 [00:01<00:05,  2.88it/s]13:23:37 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:37 - cmdstanpy - INFO - Chain [1] done processing
#  26%|██▋       | 5/19 [00:01<00:04,  2.97it/s]13:23:37 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:37 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 6/19 [00:01<00:04,  3.08it/s]13:23:37 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:37 - cmdstanpy - INFO - Chain [1] done processing
#  37%|███▋      | 7/19 [00:02<00:03,  3.22it/s]13:23:37 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:38 - cmdstanpy - INFO - Chain [1] done processing
#  42%|████▏     | 8/19 [00:02<00:03,  3.24it/s]13:23:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:38 - cmdstanpy - INFO - Chain [1] done processing
#  47%|████▋     | 9/19 [00:03<00:03,  2.81it/s]13:23:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:38 - cmdstanpy - INFO - Chain [1] done processing
#  53%|█████▎    | 10/19 [00:03<00:03,  2.91it/s]13:23:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:39 - cmdstanpy - INFO - Chain [1] done processing
#  58%|█████▊    | 11/19 [00:03<00:02,  2.98it/s]13:23:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:39 - cmdstanpy - INFO - Chain [1] done processing
#  63%|██████▎   | 12/19 [00:03<00:02,  3.07it/s]13:23:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:39 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 13/19 [00:04<00:01,  3.22it/s]13:23:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:40 - cmdstanpy - INFO - Chain [1] done processing
#  74%|███████▎  | 14/19 [00:04<00:01,  3.26it/s]13:23:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:40 - cmdstanpy - INFO - Chain [1] done processing
#  79%|███████▉  | 15/19 [00:04<00:01,  3.29it/s]13:23:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:40 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 16/19 [00:05<00:00,  3.13it/s]13:23:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:40 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▉ | 17/19 [00:05<00:00,  3.31it/s]13:23:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:41 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 18/19 [00:05<00:00,  3.02it/s]13:23:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:41 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 19/19 [00:06<00:00,  3.08it/s]
#   -> CV RMSE: 55,800 (12.13%), In-sample: 7,465 (1.62%)
#   [OK] NEW BEST (CV RMSE: 55,800, 12.13%)
#
# Try 2/22: {'changepoint_prior_scale': 0.001, 'seasonality_prior_scale': 10.0, 'seasonality_mode': 'multiplicative', 'monthly_fourier': 5, 'n_changepoints': 15}
# 13:23:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:42 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/19 [00:00<?, ?it/s]13:23:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:46 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 1/19 [00:03<01:06,  3.69s/it]13:23:46 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:46 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 2/19 [00:03<00:28,  1.68s/it]13:23:46 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:46 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 3/19 [00:04<00:17,  1.09s/it]13:23:47 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:47 - cmdstanpy - INFO - Chain [1] done processing
#  21%|██        | 4/19 [00:04<00:12,  1.23it/s]13:23:47 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:47 - cmdstanpy - INFO - Chain [1] done processing
#  26%|██▋       | 5/19 [00:05<00:09,  1.47it/s]13:23:48 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:48 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 6/19 [00:05<00:07,  1.66it/s]13:23:48 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:48 - cmdstanpy - INFO - Chain [1] done processing
#  37%|███▋      | 7/19 [00:05<00:06,  1.92it/s]13:23:48 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:49 - cmdstanpy - INFO - Chain [1] done processing
#  42%|████▏     | 8/19 [00:06<00:05,  1.89it/s]13:23:49 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:49 - cmdstanpy - INFO - Chain [1] done processing
#  47%|████▋     | 9/19 [00:07<00:05,  1.96it/s]13:23:49 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:50 - cmdstanpy - INFO - Chain [1] done processing
#  53%|█████▎    | 10/19 [00:07<00:04,  2.15it/s]13:23:50 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:50 - cmdstanpy - INFO - Chain [1] done processing
#  58%|█████▊    | 11/19 [00:07<00:03,  2.27it/s]13:23:50 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:50 - cmdstanpy - INFO - Chain [1] done processing
#  63%|██████▎   | 12/19 [00:08<00:02,  2.40it/s]13:23:50 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:51 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 13/19 [00:08<00:02,  2.49it/s]13:23:51 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:51 - cmdstanpy - INFO - Chain [1] done processing
#  74%|███████▎  | 14/19 [00:08<00:02,  2.50it/s]13:23:51 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:52 - cmdstanpy - INFO - Chain [1] done processing
#  79%|███████▉  | 15/19 [00:09<00:01,  2.02it/s]13:23:52 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:52 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 16/19 [00:09<00:01,  2.15it/s]13:23:52 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:53 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▉ | 17/19 [00:10<00:00,  2.19it/s]13:23:53 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:53 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 18/19 [00:10<00:00,  2.16it/s]13:23:53 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:53 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 19/19 [00:11<00:00,  1.69it/s]
#   -> CV RMSE: 91,562 (19.91%), In-sample: 7,544 (1.64%)
#
# Try 3/22: {'changepoint_prior_scale': 0.005, 'seasonality_prior_scale': 5.0, 'seasonality_mode': 'multiplicative', 'monthly_fourier': 3, 'n_changepoints': 10}
# 13:23:54 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:54 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/19 [00:00<?, ?it/s]13:23:54 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:54 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 1/19 [00:00<00:06,  2.68it/s]13:23:54 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:55 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 2/19 [00:00<00:07,  2.26it/s]13:23:55 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:55 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 3/19 [00:01<00:06,  2.45it/s]13:23:55 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:56 - cmdstanpy - INFO - Chain [1] done processing
#  21%|██        | 4/19 [00:01<00:07,  1.94it/s]13:23:56 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:58 - cmdstanpy - INFO - Chain [1] done processing
#  26%|██▋       | 5/19 [00:04<00:15,  1.12s/it]13:23:58 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:58 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 6/19 [00:04<00:11,  1.14it/s]13:23:59 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:59 - cmdstanpy - INFO - Chain [1] done processing
#  37%|███▋      | 7/19 [00:04<00:08,  1.38it/s]13:23:59 - cmdstanpy - INFO - Chain [1] start processing
# 13:23:59 - cmdstanpy - INFO - Chain [1] done processing
#  42%|████▏     | 8/19 [00:05<00:06,  1.63it/s]13:23:59 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:00 - cmdstanpy - INFO - Chain [1] done processing
#  47%|████▋     | 9/19 [00:05<00:05,  1.86it/s]13:24:00 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:00 - cmdstanpy - INFO - Chain [1] done processing
#  53%|█████▎    | 10/19 [00:06<00:04,  1.94it/s]13:24:00 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:00 - cmdstanpy - INFO - Chain [1] done processing
#  58%|█████▊    | 11/19 [00:06<00:03,  2.02it/s]13:24:01 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:01 - cmdstanpy - INFO - Chain [1] done processing
#  63%|██████▎   | 12/19 [00:06<00:03,  2.18it/s]13:24:01 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:01 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 13/19 [00:07<00:02,  2.32it/s]13:24:01 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:02 - cmdstanpy - INFO - Chain [1] done processing
#  74%|███████▎  | 14/19 [00:07<00:02,  2.40it/s]13:24:02 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:02 - cmdstanpy - INFO - Chain [1] done processing
#  79%|███████▉  | 15/19 [00:08<00:01,  2.52it/s]13:24:02 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:02 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 16/19 [00:08<00:01,  2.55it/s]13:24:02 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:03 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▉ | 17/19 [00:08<00:00,  2.71it/s]13:24:03 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:03 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 18/19 [00:09<00:00,  2.71it/s]13:24:03 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:03 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 19/19 [00:09<00:00,  2.00it/s]
#   -> CV RMSE: 65,561 (14.26%), In-sample: 7,465 (1.62%)
#
# Try 4/22: {'changepoint_prior_scale': 0.005, 'seasonality_prior_scale': 10.0, 'seasonality_mode': 'multiplicative', 'monthly_fourier': 5, 'n_changepoints': 15}
# 13:24:04 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:04 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/19 [00:00<?, ?it/s]13:24:04 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:09 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 1/19 [00:05<01:39,  5.54s/it]13:24:10 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:10 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 2/19 [00:06<00:43,  2.59s/it]13:24:10 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:10 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 3/19 [00:06<00:26,  1.63s/it]13:24:11 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:11 - cmdstanpy - INFO - Chain [1] done processing
#  21%|██        | 4/19 [00:06<00:17,  1.16s/it]13:24:11 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:11 - cmdstanpy - INFO - Chain [1] done processing
#  26%|██▋       | 5/19 [00:07<00:12,  1.08it/s]13:24:12 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:12 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 6/19 [00:07<00:09,  1.33it/s]13:24:12 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:12 - cmdstanpy - INFO - Chain [1] done processing
#  37%|███▋      | 7/19 [00:08<00:07,  1.54it/s]13:24:12 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:13 - cmdstanpy - INFO - Chain [1] done processing
#  42%|████▏     | 8/19 [00:08<00:06,  1.64it/s]13:24:13 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:13 - cmdstanpy - INFO - Chain [1] done processing
#  47%|████▋     | 9/19 [00:09<00:05,  1.72it/s]13:24:13 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:14 - cmdstanpy - INFO - Chain [1] done processing
#  53%|█████▎    | 10/19 [00:09<00:04,  1.80it/s]13:24:14 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:14 - cmdstanpy - INFO - Chain [1] done processing
#  58%|█████▊    | 11/19 [00:10<00:04,  1.86it/s]13:24:14 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:15 - cmdstanpy - INFO - Chain [1] done processing
#  63%|██████▎   | 12/19 [00:10<00:03,  2.01it/s]13:24:15 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:15 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 13/19 [00:11<00:03,  1.98it/s]13:24:15 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:16 - cmdstanpy - INFO - Chain [1] done processing
#  74%|███████▎  | 14/19 [00:11<00:02,  1.97it/s]13:24:16 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:16 - cmdstanpy - INFO - Chain [1] done processing
#  79%|███████▉  | 15/19 [00:12<00:01,  2.07it/s]13:24:16 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:17 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 16/19 [00:12<00:01,  2.10it/s]13:24:17 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:17 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▉ | 17/19 [00:13<00:00,  2.06it/s]13:24:17 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:17 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 18/19 [00:13<00:00,  2.20it/s]13:24:18 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:18 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 19/19 [00:14<00:00,  1.36it/s]
#   -> CV RMSE: 98,337 (21.38%), In-sample: 7,458 (1.62%)
#
# Try 5/22: {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 5.0, 'seasonality_mode': 'multiplicative', 'monthly_fourier': 3, 'n_changepoints': 10}
# 13:24:18 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:18 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/19 [00:00<?, ?it/s]13:24:18 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:19 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 1/19 [00:00<00:06,  2.62it/s]13:24:19 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:32 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 2/19 [00:13<02:12,  7.80s/it]13:24:32 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:49 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 3/19 [00:30<03:10, 11.91s/it]13:24:49 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:51 - cmdstanpy - INFO - Chain [1] done processing
#  21%|██        | 4/19 [00:32<02:00,  8.03s/it]13:24:51 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:52 - cmdstanpy - INFO - Chain [1] done processing
#  26%|██▋       | 5/19 [00:33<01:18,  5.61s/it]13:24:52 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:52 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 6/19 [00:34<00:50,  3.90s/it]13:24:53 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:53 - cmdstanpy - INFO - Chain [1] done processing
#  37%|███▋      | 7/19 [00:34<00:32,  2.75s/it]13:24:53 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:53 - cmdstanpy - INFO - Chain [1] done processing
#  42%|████▏     | 8/19 [00:34<00:21,  2.00s/it]13:24:53 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:54 - cmdstanpy - INFO - Chain [1] done processing
#  47%|████▋     | 9/19 [00:35<00:14,  1.49s/it]13:24:54 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:54 - cmdstanpy - INFO - Chain [1] done processing
#  53%|█████▎    | 10/19 [00:35<00:10,  1.15s/it]13:24:54 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:54 - cmdstanpy - INFO - Chain [1] done processing
#  58%|█████▊    | 11/19 [00:36<00:07,  1.08it/s]13:24:55 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:55 - cmdstanpy - INFO - Chain [1] done processing
#  63%|██████▎   | 12/19 [00:36<00:05,  1.36it/s]13:24:55 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:55 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 13/19 [00:36<00:03,  1.65it/s]13:24:55 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:55 - cmdstanpy - INFO - Chain [1] done processing
#  74%|███████▎  | 14/19 [00:37<00:02,  1.92it/s]13:24:56 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:56 - cmdstanpy - INFO - Chain [1] done processing
#  79%|███████▉  | 15/19 [00:37<00:01,  2.24it/s]13:24:56 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:56 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 16/19 [00:37<00:01,  2.23it/s]13:24:56 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:56 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▉ | 17/19 [00:38<00:00,  2.59it/s]13:24:56 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:57 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 18/19 [00:38<00:00,  2.80it/s]13:24:57 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:57 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 19/19 [00:38<00:00,  2.03s/it]
#   -> CV RMSE: 91,074 (19.81%), In-sample: 7,465 (1.62%)
#
# Try 6/22: {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 8.0, 'seasonality_mode': 'multiplicative', 'monthly_fourier': 5, 'n_changepoints': 15}
# 13:24:57 - cmdstanpy - INFO - Chain [1] start processing
# 13:24:57 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/19 [00:00<?, ?it/s]13:24:58 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:00 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 1/19 [00:02<00:46,  2.56s/it]13:25:00 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:08 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 2/19 [00:10<01:38,  5.82s/it]13:25:08 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:15 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 3/19 [00:17<01:42,  6.42s/it]13:25:15 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:16 - cmdstanpy - INFO - Chain [1] done processing
#  21%|██        | 4/19 [00:18<01:01,  4.10s/it]13:25:16 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:16 - cmdstanpy - INFO - Chain [1] done processing
#  26%|██▋       | 5/19 [00:19<00:40,  2.87s/it]13:25:17 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:17 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 6/19 [00:19<00:26,  2.07s/it]13:25:17 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:18 - cmdstanpy - INFO - Chain [1] done processing
#  37%|███▋      | 7/19 [00:20<00:19,  1.60s/it]13:25:18 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:18 - cmdstanpy - INFO - Chain [1] done processing
#  42%|████▏     | 8/19 [00:20<00:14,  1.33s/it]13:25:18 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:19 - cmdstanpy - INFO - Chain [1] done processing
#  47%|████▋     | 9/19 [00:21<00:11,  1.14s/it]13:25:19 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:20 - cmdstanpy - INFO - Chain [1] done processing
#  53%|█████▎    | 10/19 [00:22<00:08,  1.02it/s]13:25:20 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:20 - cmdstanpy - INFO - Chain [1] done processing
#  58%|█████▊    | 11/19 [00:23<00:07,  1.06it/s]13:25:21 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:21 - cmdstanpy - INFO - Chain [1] done processing
#  63%|██████▎   | 12/19 [00:23<00:05,  1.22it/s]13:25:21 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:22 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 13/19 [00:24<00:04,  1.36it/s]13:25:22 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:22 - cmdstanpy - INFO - Chain [1] done processing
#  74%|███████▎  | 14/19 [00:24<00:03,  1.49it/s]13:25:22 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:23 - cmdstanpy - INFO - Chain [1] done processing
#  79%|███████▉  | 15/19 [00:25<00:02,  1.67it/s]13:25:23 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:23 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 16/19 [00:25<00:01,  1.78it/s]13:25:23 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:27 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▉ | 17/19 [00:29<00:03,  1.68s/it]13:25:28 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:28 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 18/19 [00:30<00:01,  1.33s/it]13:25:28 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:28 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 19/19 [00:30<00:00,  1.63s/it]
#   -> CV RMSE: 103,681 (22.55%), In-sample: 7,456 (1.62%)
#
# Try 7/22: {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 10.0, 'seasonality_mode': 'multiplicative', 'monthly_fourier': 5, 'n_changepoints': 20}
# 13:25:29 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:29 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/19 [00:00<?, ?it/s]13:25:29 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:37 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 1/19 [00:08<02:27,  8.22s/it]13:25:37 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:41 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 2/19 [00:12<01:35,  5.64s/it]13:25:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:45 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 3/19 [00:16<01:18,  4.91s/it]13:25:45 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:45 - cmdstanpy - INFO - Chain [1] done processing
#  21%|██        | 4/19 [00:16<00:46,  3.10s/it]13:25:45 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:46 - cmdstanpy - INFO - Chain [1] done processing
#  26%|██▋       | 5/19 [00:16<00:29,  2.10s/it]13:25:46 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:46 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 6/19 [00:17<00:19,  1.49s/it]13:25:46 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:46 - cmdstanpy - INFO - Chain [1] done processing
#  37%|███▋      | 7/19 [00:17<00:13,  1.13s/it]13:25:46 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:47 - cmdstanpy - INFO - Chain [1] done processing
#  42%|████▏     | 8/19 [00:17<00:09,  1.12it/s]13:25:47 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:47 - cmdstanpy - INFO - Chain [1] done processing
#  47%|████▋     | 9/19 [00:18<00:07,  1.37it/s]13:25:47 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:47 - cmdstanpy - INFO - Chain [1] done processing
#  53%|█████▎    | 10/19 [00:18<00:05,  1.59it/s]13:25:48 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:48 - cmdstanpy - INFO - Chain [1] done processing
#  58%|█████▊    | 11/19 [00:19<00:04,  1.72it/s]13:25:48 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:48 - cmdstanpy - INFO - Chain [1] done processing
#  63%|██████▎   | 12/19 [00:19<00:03,  1.98it/s]13:25:48 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:49 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 13/19 [00:19<00:02,  2.10it/s]13:25:49 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:49 - cmdstanpy - INFO - Chain [1] done processing
#  74%|███████▎  | 14/19 [00:20<00:02,  2.17it/s]13:25:49 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:49 - cmdstanpy - INFO - Chain [1] done processing
#  79%|███████▉  | 15/19 [00:20<00:01,  2.43it/s]13:25:50 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:50 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 16/19 [00:20<00:01,  2.52it/s]13:25:50 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:50 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▉ | 17/19 [00:21<00:00,  2.56it/s]13:25:50 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:50 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 18/19 [00:21<00:00,  2.74it/s]13:25:51 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:51 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 19/19 [00:21<00:00,  1.15s/it]
#   -> CV RMSE: 106,186 (23.09%), In-sample: 7,453 (1.62%)
#
# Try 8/22: {'changepoint_prior_scale': 0.02, 'seasonality_prior_scale': 5.0, 'seasonality_mode': 'multiplicative', 'monthly_fourier': 3, 'n_changepoints': 10}
# 13:25:51 - cmdstanpy - INFO - Chain [1] start processing
# 13:25:51 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/19 [00:00<?, ?it/s]13:25:51 - cmdstanpy - INFO - Chain [1] start processing
# 13:26:09 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 1/19 [00:18<05:30, 18.35s/it]13:26:10 - cmdstanpy - INFO - Chain [1] start processing
# 13:26:27 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 2/19 [00:35<05:02, 17.82s/it]13:26:27 - cmdstanpy - INFO - Chain [1] start processing
# 13:26:43 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 3/19 [00:51<04:31, 16.94s/it]13:26:43 - cmdstanpy - INFO - Chain [1] start processing
# 13:26:46 - cmdstanpy - INFO - Chain [1] done processing
#  21%|██        | 4/19 [00:55<02:55, 11.68s/it]13:26:47 - cmdstanpy - INFO - Chain [1] start processing
# 13:26:47 - cmdstanpy - INFO - Chain [1] done processing
#  26%|██▋       | 5/19 [00:56<01:49,  7.85s/it]13:26:48 - cmdstanpy - INFO - Chain [1] start processing
# 13:26:48 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 6/19 [00:56<01:08,  5.29s/it]13:26:48 - cmdstanpy - INFO - Chain [1] start processing
# 13:26:49 - cmdstanpy - INFO - Chain [1] done processing
#  37%|███▋      | 7/19 [00:57<00:46,  3.90s/it]13:26:49 - cmdstanpy - INFO - Chain [1] start processing
# 13:26:49 - cmdstanpy - INFO - Chain [1] done processing
#  42%|████▏     | 8/19 [00:58<00:31,  2.84s/it]13:26:50 - cmdstanpy - INFO - Chain [1] start processing
# 13:26:50 - cmdstanpy - INFO - Chain [1] done processing
#  47%|████▋     | 9/19 [00:59<00:22,  2.22s/it]13:26:50 - cmdstanpy - INFO - Chain [1] start processing
# 13:26:50 - cmdstanpy - INFO - Chain [1] done processing
#  53%|█████▎    | 10/19 [00:59<00:14,  1.60s/it]13:26:51 - cmdstanpy - INFO - Chain [1] start processing
# 13:26:52 - cmdstanpy - INFO - Chain [1] done processing
#  58%|█████▊    | 11/19 [01:00<00:11,  1.46s/it]13:26:52 - cmdstanpy - INFO - Chain [1] start processing
# 13:26:52 - cmdstanpy - INFO - Chain [1] done processing
#  63%|██████▎   | 12/19 [01:00<00:07,  1.08s/it]13:26:52 - cmdstanpy - INFO - Chain [1] start processing
# 13:26:52 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 13/19 [01:01<00:05,  1.18it/s]13:26:52 - cmdstanpy - INFO - Chain [1] start processing
# 13:26:53 - cmdstanpy - INFO - Chain [1] done processing
#  74%|███████▎  | 14/19 [01:01<00:04,  1.16it/s]13:26:53 - cmdstanpy - INFO - Chain [1] start processing
# 13:26:53 - cmdstanpy - INFO - Chain [1] done processing
#  79%|███████▉  | 15/19 [01:02<00:02,  1.51it/s]13:26:53 - cmdstanpy - INFO - Chain [1] start processing
# 13:26:54 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 16/19 [01:02<00:01,  1.81it/s]13:26:54 - cmdstanpy - INFO - Chain [1] start processing
# 13:26:54 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▉ | 17/19 [01:02<00:00,  2.17it/s]13:26:54 - cmdstanpy - INFO - Chain [1] start processing
# 13:26:54 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 18/19 [01:02<00:00,  2.51it/s]13:26:54 - cmdstanpy - INFO - Chain [1] start processing
# 13:26:54 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 19/19 [01:03<00:00,  3.33s/it]
#   -> CV RMSE: 97,004 (21.09%), In-sample: 7,461 (1.62%)
#
# Try 9/22: {'changepoint_prior_scale': 0.02, 'seasonality_prior_scale': 8.0, 'seasonality_mode': 'multiplicative', 'monthly_fourier': 5, 'n_changepoints': 15}
# 13:26:55 - cmdstanpy - INFO - Chain [1] start processing
# 13:26:55 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/19 [00:00<?, ?it/s]13:26:55 - cmdstanpy - INFO - Chain [1] start processing
# 13:27:11 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 1/19 [00:16<05:00, 16.68s/it]13:27:12 - cmdstanpy - INFO - Chain [1] start processing
# 13:27:28 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 2/19 [00:33<04:46, 16.84s/it]13:27:28 - cmdstanpy - INFO - Chain [1] start processing
# 13:27:40 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 3/19 [00:45<03:52, 14.51s/it]13:27:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:27:40 - cmdstanpy - INFO - Chain [1] done processing
#  21%|██        | 4/19 [00:45<02:13,  8.92s/it]13:27:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:27:41 - cmdstanpy - INFO - Chain [1] done processing
#  26%|██▋       | 5/19 [00:46<01:22,  5.88s/it]13:27:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:27:41 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 6/19 [00:46<00:52,  4.04s/it]13:27:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:27:42 - cmdstanpy - INFO - Chain [1] done processing
#  37%|███▋      | 7/19 [00:47<00:35,  2.93s/it]13:27:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:28:01 - cmdstanpy - INFO - Chain [1] done processing
#  42%|████▏     | 8/19 [01:06<01:28,  8.02s/it]13:28:01 - cmdstanpy - INFO - Chain [1] start processing
# 13:28:19 - cmdstanpy - INFO - Chain [1] done processing
#  47%|████▋     | 9/19 [01:24<01:51, 11.16s/it]13:28:19 - cmdstanpy - INFO - Chain [1] start processing
# 13:28:38 - cmdstanpy - INFO - Chain [1] done processing
#  53%|█████▎    | 10/19 [01:43<02:01, 13.51s/it]13:28:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:28:58 - cmdstanpy - INFO - Chain [1] done processing
#  58%|█████▊    | 11/19 [02:02<02:03, 15.47s/it]13:28:58 - cmdstanpy - INFO - Chain [1] start processing
# 13:28:58 - cmdstanpy - INFO - Chain [1] done processing
#  63%|██████▎   | 12/19 [02:03<01:16, 10.93s/it]13:28:58 - cmdstanpy - INFO - Chain [1] start processing
# 13:28:59 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 13/19 [02:04<00:46,  7.78s/it]13:28:59 - cmdstanpy - INFO - Chain [1] start processing
# 13:29:02 - cmdstanpy - INFO - Chain [1] done processing
#  74%|███████▎  | 14/19 [02:07<00:32,  6.41s/it]13:29:02 - cmdstanpy - INFO - Chain [1] start processing
# 13:29:02 - cmdstanpy - INFO - Chain [1] done processing
#  79%|███████▉  | 15/19 [02:07<00:18,  4.61s/it]13:29:03 - cmdstanpy - INFO - Chain [1] start processing
# 13:29:03 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 16/19 [02:08<00:10,  3.36s/it]13:29:03 - cmdstanpy - INFO - Chain [1] start processing
# 13:29:03 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▉ | 17/19 [02:08<00:04,  2.48s/it]13:29:04 - cmdstanpy - INFO - Chain [1] start processing
# 13:29:04 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 18/19 [02:09<00:01,  1.86s/it]13:29:04 - cmdstanpy - INFO - Chain [1] start processing
# 13:29:04 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 19/19 [02:09<00:00,  6.82s/it]
#   -> CV RMSE: 99,237 (21.58%), In-sample: 7,447 (1.62%)
#
# Try 10/22: {'changepoint_prior_scale': 0.03, 'seasonality_prior_scale': 5.0, 'seasonality_mode': 'multiplicative', 'monthly_fourier': 3, 'n_changepoints': 10}
# 13:29:04 - cmdstanpy - INFO - Chain [1] start processing
# 13:29:05 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/19 [00:00<?, ?it/s]13:29:06 - cmdstanpy - INFO - Chain [1] start processing
# 13:29:18 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 1/19 [00:12<03:46, 12.59s/it]13:29:18 - cmdstanpy - INFO - Chain [1] start processing
# 13:29:45 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 2/19 [00:39<05:59, 21.15s/it]13:29:45 - cmdstanpy - INFO - Chain [1] start processing
# 13:30:05 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 3/19 [01:00<05:32, 20.79s/it]13:30:06 - cmdstanpy - INFO - Chain [1] start processing
# 13:30:25 - cmdstanpy - INFO - Chain [1] done processing
#  21%|██        | 4/19 [01:19<05:04, 20.29s/it]13:30:25 - cmdstanpy - INFO - Chain [1] start processing
# 13:30:30 - cmdstanpy - INFO - Chain [1] done processing
#  26%|██▋       | 5/19 [01:25<03:28, 14.93s/it]13:30:31 - cmdstanpy - INFO - Chain [1] start processing
# 13:30:31 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 6/19 [01:25<02:10, 10.05s/it]13:30:31 - cmdstanpy - INFO - Chain [1] start processing
# 13:30:32 - cmdstanpy - INFO - Chain [1] done processing
#  37%|███▋      | 7/19 [01:26<01:25,  7.12s/it]13:30:32 - cmdstanpy - INFO - Chain [1] start processing
# 13:30:33 - cmdstanpy - INFO - Chain [1] done processing
#  42%|████▏     | 8/19 [01:28<00:58,  5.28s/it]13:30:34 - cmdstanpy - INFO - Chain [1] start processing
# 13:30:35 - cmdstanpy - INFO - Chain [1] done processing
#  47%|████▋     | 9/19 [01:29<00:39,  3.98s/it]13:30:35 - cmdstanpy - INFO - Chain [1] start processing
# 13:30:36 - cmdstanpy - INFO - Chain [1] done processing
#  53%|█████▎    | 10/19 [01:30<00:28,  3.21s/it]13:30:36 - cmdstanpy - INFO - Chain [1] start processing
# 13:30:37 - cmdstanpy - INFO - Chain [1] done processing
#  58%|█████▊    | 11/19 [01:31<00:20,  2.55s/it]13:30:37 - cmdstanpy - INFO - Chain [1] start processing
# 13:30:37 - cmdstanpy - INFO - Chain [1] done processing
#  63%|██████▎   | 12/19 [01:32<00:13,  1.88s/it]13:30:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:30:38 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 13/19 [01:32<00:08,  1.43s/it]13:30:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:30:39 - cmdstanpy - INFO - Chain [1] done processing
#  74%|███████▎  | 14/19 [01:33<00:06,  1.35s/it]13:30:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:30:39 - cmdstanpy - INFO - Chain [1] done processing
#  79%|███████▉  | 15/19 [01:33<00:04,  1.05s/it]13:30:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:30:40 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 16/19 [01:34<00:02,  1.17it/s]13:30:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:30:40 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▉ | 17/19 [01:34<00:01,  1.34it/s]13:30:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:30:41 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 18/19 [01:35<00:00,  1.55it/s]13:30:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:30:41 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 19/19 [01:35<00:00,  5.05s/it]
#   -> CV RMSE: 99,288 (21.59%), In-sample: 6,810 (1.48%)
#
# Try 11/22: {'changepoint_prior_scale': 0.05, 'seasonality_prior_scale': 5.0, 'seasonality_mode': 'multiplicative', 'monthly_fourier': 3, 'n_changepoints': 10}
# 13:30:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:30:42 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/19 [00:00<?, ?it/s]13:30:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:31:04 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 1/19 [00:22<06:36, 22.04s/it]13:31:05 - cmdstanpy - INFO - Chain [1] start processing
# 13:31:31 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 2/19 [00:49<07:05, 25.03s/it]13:31:32 - cmdstanpy - INFO - Chain [1] start processing
# 13:31:48 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 3/19 [01:06<05:41, 21.32s/it]13:31:49 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:04 - cmdstanpy - INFO - Chain [1] done processing
#  21%|██        | 4/19 [01:21<04:47, 19.14s/it]13:32:04 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:06 - cmdstanpy - INFO - Chain [1] done processing
#  26%|██▋       | 5/19 [01:23<02:58, 12.73s/it]13:32:06 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:06 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 6/19 [01:23<01:50,  8.53s/it]13:32:06 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:21 - cmdstanpy - INFO - Chain [1] done processing
#  37%|███▋      | 7/19 [01:38<02:06, 10.54s/it]13:32:21 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:21 - cmdstanpy - INFO - Chain [1] done processing
#  42%|████▏     | 8/19 [01:39<01:21,  7.42s/it]13:32:22 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:37 - cmdstanpy - INFO - Chain [1] done processing
#  47%|████▋     | 9/19 [01:55<01:41, 10.13s/it]13:32:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:38 - cmdstanpy - INFO - Chain [1] done processing
#  53%|█████▎    | 10/19 [01:55<01:04,  7.17s/it]13:32:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:39 - cmdstanpy - INFO - Chain [1] done processing
#  58%|█████▊    | 11/19 [01:56<00:41,  5.15s/it]13:32:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:39 - cmdstanpy - INFO - Chain [1] done processing
#  63%|██████▎   | 12/19 [01:56<00:25,  3.67s/it]13:32:39 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:41 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 13/19 [01:58<00:19,  3.21s/it]13:32:41 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:41 - cmdstanpy - INFO - Chain [1] done processing
#  74%|███████▎  | 14/19 [01:59<00:11,  2.37s/it]13:32:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:42 - cmdstanpy - INFO - Chain [1] done processing
#  79%|███████▉  | 15/19 [01:59<00:06,  1.73s/it]13:32:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:42 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 16/19 [01:59<00:03,  1.30s/it]13:32:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:42 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▉ | 17/19 [01:59<00:01,  1.02it/s]13:32:42 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:42 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 18/19 [02:00<00:00,  1.32it/s]13:32:43 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:43 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 19/19 [02:00<00:00,  6.36s/it]
#   -> CV RMSE: 98,958 (21.52%), In-sample: 6,762 (1.47%)
#
# Try 12/22: {'changepoint_prior_scale': 0.05, 'seasonality_prior_scale': 10.0, 'seasonality_mode': 'multiplicative', 'monthly_fourier': 5, 'n_changepoints': 15}
# 13:32:43 - cmdstanpy - INFO - Chain [1] start processing
# 13:32:45 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/19 [00:00<?, ?it/s]13:32:45 - cmdstanpy - INFO - Chain [1] start processing
# 13:33:56 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 1/19 [01:11<21:21, 71.20s/it]13:33:56 - cmdstanpy - INFO - Chain [1] start processing
# 13:34:13 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 2/19 [01:28<11:12, 39.53s/it]13:34:13 - cmdstanpy - INFO - Chain [1] start processing
# 13:34:30 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 3/19 [01:45<07:49, 29.37s/it]13:34:30 - cmdstanpy - INFO - Chain [1] start processing
# 13:34:50 - cmdstanpy - INFO - Chain [1] done processing
#  21%|██        | 4/19 [02:05<06:20, 25.39s/it]13:34:50 - cmdstanpy - INFO - Chain [1] start processing
# 13:35:07 - cmdstanpy - INFO - Chain [1] done processing
#  26%|██▋       | 5/19 [02:22<05:13, 22.38s/it]13:35:07 - cmdstanpy - INFO - Chain [1] start processing
# 13:35:24 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 6/19 [02:39<04:29, 20.76s/it]13:35:24 - cmdstanpy - INFO - Chain [1] start processing
# 13:35:42 - cmdstanpy - INFO - Chain [1] done processing
#  37%|███▋      | 7/19 [02:57<03:58, 19.91s/it]13:35:43 - cmdstanpy - INFO - Chain [1] start processing
# 13:36:01 - cmdstanpy - INFO - Chain [1] done processing
#  42%|████▏     | 8/19 [03:16<03:33, 19.45s/it]13:36:01 - cmdstanpy - INFO - Chain [1] start processing
# 13:36:19 - cmdstanpy - INFO - Chain [1] done processing
#  47%|████▋     | 9/19 [03:34<03:09, 18.97s/it]13:36:19 - cmdstanpy - INFO - Chain [1] start processing
# 13:36:38 - cmdstanpy - INFO - Chain [1] done processing
#  53%|█████▎    | 10/19 [03:53<02:51, 19.04s/it]13:36:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:36:57 - cmdstanpy - INFO - Chain [1] done processing
#  58%|█████▊    | 11/19 [04:12<02:32, 19.05s/it]13:36:57 - cmdstanpy - INFO - Chain [1] start processing
# 13:36:57 - cmdstanpy - INFO - Chain [1] done processing
#  63%|██████▎   | 12/19 [04:12<01:33, 13.35s/it]13:36:58 - cmdstanpy - INFO - Chain [1] start processing
# 13:36:59 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 13/19 [04:14<00:58,  9.67s/it]13:36:59 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:01 - cmdstanpy - INFO - Chain [1] done processing
#  74%|███████▎  | 14/19 [04:16<00:36,  7.33s/it]13:37:01 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:01 - cmdstanpy - INFO - Chain [1] done processing
#  79%|███████▉  | 15/19 [04:16<00:20,  5.21s/it]13:37:01 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:01 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 16/19 [04:16<00:11,  3.79s/it]13:37:01 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:02 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▉ | 17/19 [04:17<00:05,  2.77s/it]13:37:02 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:02 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 18/19 [04:17<00:02,  2.09s/it]13:37:02 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:04 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 19/19 [04:19<00:00, 13.68s/it]
#   -> CV RMSE: 124,315 (27.03%), In-sample: 6,374 (1.39%)
#
# Try 13/22: {'changepoint_prior_scale': 0.001, 'seasonality_prior_scale': 5.0, 'seasonality_mode': 'additive', 'monthly_fourier': 3, 'n_changepoints': 10}
# 13:37:05 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:05 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/19 [00:00<?, ?it/s]13:37:05 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:05 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 1/19 [00:00<00:05,  3.32it/s]13:37:05 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:05 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 2/19 [00:00<00:05,  3.17it/s]13:37:06 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:06 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 3/19 [00:00<00:05,  3.20it/s]13:37:06 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:06 - cmdstanpy - INFO - Chain [1] done processing
#  21%|██        | 4/19 [00:01<00:04,  3.03it/s]13:37:06 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:06 - cmdstanpy - INFO - Chain [1] done processing
#  26%|██▋       | 5/19 [00:01<00:04,  3.04it/s]13:37:07 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:07 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 6/19 [00:01<00:04,  3.04it/s]13:37:07 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:07 - cmdstanpy - INFO - Chain [1] done processing
#  37%|███▋      | 7/19 [00:02<00:03,  3.04it/s]13:37:07 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:07 - cmdstanpy - INFO - Chain [1] done processing
#  42%|████▏     | 8/19 [00:02<00:03,  3.06it/s]13:37:08 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:08 - cmdstanpy - INFO - Chain [1] done processing
#  47%|████▋     | 9/19 [00:02<00:03,  3.05it/s]13:37:08 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:08 - cmdstanpy - INFO - Chain [1] done processing
#  53%|█████▎    | 10/19 [00:03<00:02,  3.20it/s]13:37:08 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:08 - cmdstanpy - INFO - Chain [1] done processing
#  58%|█████▊    | 11/19 [00:03<00:02,  3.05it/s]13:37:08 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:09 - cmdstanpy - INFO - Chain [1] done processing
#  63%|██████▎   | 12/19 [00:03<00:02,  3.16it/s]13:37:09 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:09 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 13/19 [00:04<00:01,  3.18it/s]13:37:09 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:09 - cmdstanpy - INFO - Chain [1] done processing
#  74%|███████▎  | 14/19 [00:04<00:01,  2.97it/s]13:37:09 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:10 - cmdstanpy - INFO - Chain [1] done processing
#  79%|███████▉  | 15/19 [00:05<00:01,  2.53it/s]13:37:10 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:10 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 16/19 [00:05<00:01,  2.68it/s]13:37:10 - cmdstanpy - INFO - Chain [1] start processing
# 13:37:10 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▉ | 17/19 [00:05<00:00,  2.87it/s]13:37:11 - cmdstanpy - INFO - Chain [1] start processing
# ...
#  74%|███████▎  | 14/19 [00:30<00:01,  2.55it/s]13:38:43 - cmdstanpy - INFO - Chain [1] start processing
# 13:38:43 - cmdstanpy - INFO - Chain [1] done processing
#  79%|███████▉  | 15/19 [00:30<00:01,  2.80it/s]13:38:43 - cmdstanpy - INFO - Chain [1] start processing
# 13:38:43 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 16/19 [00:30<00:00,  3.04it/s]13:38:44 - cmdstanpy - INFO - Chain [1] start processing
# 13:38:44 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▉ | 17/19 [00:31<00:00,  3.18it/s]13:38:44 - cmdstanpy - INFO - Chain [1] start processing
# 13:38:44 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 18/19 [00:31<00:00,  3.23it/s]13:38:44 - cmdstanpy - INFO - Chain [1] start processing
# 13:38:44 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 19/19 [00:31<00:00,  1.67s/it]
#   -> CV RMSE: 83,785 (18.22%), In-sample: 7,432 (1.62%)
#
# Try 19/22: {'changepoint_prior_scale': 0.03, 'seasonality_prior_scale': 5.0, 'seasonality_mode': 'additive', 'monthly_fourier': 3, 'n_changepoints': 10}
# 13:38:44 - cmdstanpy - INFO - Chain [1] start processing
# 13:38:45 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/19 [00:00<?, ?it/s]13:38:45 - cmdstanpy - INFO - Chain [1] start processing
# 13:38:48 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 1/19 [00:03<01:02,  3.49s/it]13:38:48 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:01 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 2/19 [00:16<02:35,  9.17s/it]13:39:01 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:17 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 3/19 [00:31<03:11, 11.97s/it]13:39:17 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:17 - cmdstanpy - INFO - Chain [1] done processing
#  21%|██        | 4/19 [00:32<01:52,  7.49s/it]13:39:17 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:18 - cmdstanpy - INFO - Chain [1] done processing
#  26%|██▋       | 5/19 [00:33<01:10,  5.03s/it]13:39:18 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:18 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 6/19 [00:33<00:45,  3.52s/it]13:39:19 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:19 - cmdstanpy - INFO - Chain [1] done processing
#  37%|███▋      | 7/19 [00:34<00:30,  2.53s/it]13:39:19 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:19 - cmdstanpy - INFO - Chain [1] done processing
#  42%|████▏     | 8/19 [00:34<00:20,  1.86s/it]13:39:20 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:20 - cmdstanpy - INFO - Chain [1] done processing
#  47%|████▋     | 9/19 [00:35<00:14,  1.41s/it]13:39:20 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:20 - cmdstanpy - INFO - Chain [1] done processing
#  53%|█████▎    | 10/19 [00:35<00:09,  1.09s/it]13:39:20 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:20 - cmdstanpy - INFO - Chain [1] done processing
#  58%|█████▊    | 11/19 [00:35<00:06,  1.16it/s]13:39:21 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:21 - cmdstanpy - INFO - Chain [1] done processing
#  63%|██████▎   | 12/19 [00:36<00:04,  1.46it/s]13:39:21 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:21 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 13/19 [00:36<00:03,  1.73it/s]13:39:21 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:21 - cmdstanpy - INFO - Chain [1] done processing
#  74%|███████▎  | 14/19 [00:36<00:02,  2.02it/s]13:39:22 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:22 - cmdstanpy - INFO - Chain [1] done processing
#  79%|███████▉  | 15/19 [00:37<00:01,  2.31it/s]13:39:22 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:22 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 16/19 [00:37<00:01,  2.54it/s]13:39:22 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:22 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▉ | 17/19 [00:37<00:00,  2.69it/s]13:39:22 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:23 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 18/19 [00:38<00:00,  1.93it/s]13:39:23 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:24 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 19/19 [00:39<00:00,  2.06s/it]
#   -> CV RMSE: 85,317 (18.55%), In-sample: 7,209 (1.57%)
#
# Try 20/22: {'changepoint_prior_scale': 0.05, 'seasonality_prior_scale': 5.0, 'seasonality_mode': 'additive', 'monthly_fourier': 3, 'n_changepoints': 10}
# 13:39:24 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:24 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/19 [00:00<?, ?it/s]13:39:24 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:38 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 1/19 [00:13<04:01, 13.43s/it]13:39:38 - cmdstanpy - INFO - Chain [1] start processing
# 13:39:51 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 2/19 [00:26<03:42, 13.11s/it]13:39:51 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:03 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 3/19 [00:39<03:27, 12.98s/it]13:40:04 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:04 - cmdstanpy - INFO - Chain [1] done processing
#  21%|██        | 4/19 [00:39<01:59,  7.96s/it]13:40:04 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:04 - cmdstanpy - INFO - Chain [1] done processing
#  26%|██▋       | 5/19 [00:39<01:12,  5.19s/it]13:40:04 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:04 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 6/19 [00:39<00:45,  3.52s/it]13:40:04 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:05 - cmdstanpy - INFO - Chain [1] done processing
#  37%|███▋      | 7/19 [00:40<00:29,  2.45s/it]13:40:05 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:05 - cmdstanpy - INFO - Chain [1] done processing
#  42%|████▏     | 8/19 [00:40<00:19,  1.76s/it]13:40:05 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:05 - cmdstanpy - INFO - Chain [1] done processing
#  47%|████▋     | 9/19 [00:40<00:12,  1.30s/it]13:40:05 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:05 - cmdstanpy - INFO - Chain [1] done processing
#  53%|█████▎    | 10/19 [00:41<00:09,  1.00s/it]13:40:06 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:06 - cmdstanpy - INFO - Chain [1] done processing
#  58%|█████▊    | 11/19 [00:41<00:06,  1.27it/s]13:40:06 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:06 - cmdstanpy - INFO - Chain [1] done processing
#  63%|██████▎   | 12/19 [00:41<00:04,  1.58it/s]13:40:06 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:06 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 13/19 [00:41<00:03,  1.95it/s]13:40:06 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:07 - cmdstanpy - INFO - Chain [1] done processing
#  74%|███████▎  | 14/19 [00:42<00:02,  2.18it/s]13:40:07 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:07 - cmdstanpy - INFO - Chain [1] done processing
#  79%|███████▉  | 15/19 [00:42<00:01,  2.48it/s]13:40:07 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:07 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 16/19 [00:42<00:01,  2.82it/s]13:40:07 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:07 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▉ | 17/19 [00:43<00:00,  3.10it/s]13:40:07 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:08 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 18/19 [00:43<00:00,  3.15it/s]13:40:08 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:08 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 19/19 [00:43<00:00,  2.30s/it]
#   -> CV RMSE: 87,195 (18.96%), In-sample: 7,119 (1.55%)
#
# Try 21/22: {'changepoint_prior_scale': 0.05, 'seasonality_prior_scale': 10.0, 'seasonality_mode': 'additive', 'monthly_fourier': 5, 'n_changepoints': 15}
# 13:40:08 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:08 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/19 [00:00<?, ?it/s]13:40:08 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:27 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 1/19 [00:18<05:28, 18.23s/it]13:40:27 - cmdstanpy - INFO - Chain [1] start processing
# 13:40:43 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 2/19 [00:34<04:47, 16.92s/it]13:40:43 - cmdstanpy - INFO - Chain [1] start processing
# 13:41:50 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 3/19 [01:41<10:39, 39.99s/it]13:41:50 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:08 - cmdstanpy - INFO - Chain [1] done processing
#  21%|██        | 4/19 [01:59<07:47, 31.17s/it]13:42:08 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:08 - cmdstanpy - INFO - Chain [1] done processing
#  26%|██▋       | 5/19 [01:59<04:40, 20.02s/it]13:42:08 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:08 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 6/19 [01:59<02:53, 13.32s/it]13:42:08 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:09 - cmdstanpy - INFO - Chain [1] done processing
#  37%|███▋      | 7/19 [02:00<01:48,  9.08s/it]13:42:09 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:09 - cmdstanpy - INFO - Chain [1] done processing
#  42%|████▏     | 8/19 [02:00<01:09,  6.31s/it]13:42:09 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:09 - cmdstanpy - INFO - Chain [1] done processing
#  47%|████▋     | 9/19 [02:00<00:44,  4.44s/it]13:42:09 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:10 - cmdstanpy - INFO - Chain [1] done processing
#  53%|█████▎    | 10/19 [02:01<00:28,  3.19s/it]13:42:10 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:10 - cmdstanpy - INFO - Chain [1] done processing
#  58%|█████▊    | 11/19 [02:01<00:18,  2.33s/it]13:42:10 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:10 - cmdstanpy - INFO - Chain [1] done processing
#  63%|██████▎   | 12/19 [02:02<00:11,  1.71s/it]13:42:10 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:11 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 13/19 [02:02<00:07,  1.30s/it]13:42:11 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:11 - cmdstanpy - INFO - Chain [1] done processing
#  74%|███████▎  | 14/19 [02:02<00:05,  1.04s/it]13:42:11 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:11 - cmdstanpy - INFO - Chain [1] done processing
#  79%|███████▉  | 15/19 [02:03<00:03,  1.21it/s]13:42:12 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:12 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 16/19 [02:03<00:01,  1.51it/s]13:42:12 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:12 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▉ | 17/19 [02:03<00:01,  1.78it/s]13:42:12 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:12 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 18/19 [02:04<00:00,  2.00it/s]13:42:13 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:13 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 19/19 [02:04<00:00,  6.55s/it]
#   -> CV RMSE: 168,433 (36.63%), In-sample: 7,009 (1.52%)
#
# Try 22/22: {'changepoint_prior_scale': 0.08, 'seasonality_prior_scale': 5.0, 'seasonality_mode': 'additive', 'monthly_fourier': 3, 'n_changepoints': 10}
# 13:42:13 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:13 - cmdstanpy - INFO - Chain [1] done processing
#   0%|          | 0/19 [00:00<?, ?it/s]13:42:13 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:26 - cmdstanpy - INFO - Chain [1] done processing
#   5%|▌         | 1/19 [00:13<03:59, 13.32s/it]13:42:27 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:40 - cmdstanpy - INFO - Chain [1] done processing
#  11%|█         | 2/19 [00:26<03:48, 13.45s/it]13:42:40 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:54 - cmdstanpy - INFO - Chain [1] done processing
#  16%|█▌        | 3/19 [00:41<03:42, 13.89s/it]13:42:54 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:55 - cmdstanpy - INFO - Chain [1] done processing
#  21%|██        | 4/19 [00:41<02:07,  8.50s/it]13:42:55 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:55 - cmdstanpy - INFO - Chain [1] done processing
#  26%|██▋       | 5/19 [00:41<01:17,  5.55s/it]13:42:55 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:55 - cmdstanpy - INFO - Chain [1] done processing
#  32%|███▏      | 6/19 [00:42<00:48,  3.76s/it]13:42:55 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:55 - cmdstanpy - INFO - Chain [1] done processing
#  37%|███▋      | 7/19 [00:42<00:31,  2.62s/it]13:42:56 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:56 - cmdstanpy - INFO - Chain [1] done processing
#  42%|████▏     | 8/19 [00:42<00:20,  1.89s/it]13:42:56 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:56 - cmdstanpy - INFO - Chain [1] done processing
#  47%|████▋     | 9/19 [00:43<00:14,  1.41s/it]13:42:56 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:57 - cmdstanpy - INFO - Chain [1] done processing
#  53%|█████▎    | 10/19 [00:43<00:09,  1.09s/it]13:42:57 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:57 - cmdstanpy - INFO - Chain [1] done processing
#  58%|█████▊    | 11/19 [00:43<00:06,  1.20it/s]13:42:57 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:57 - cmdstanpy - INFO - Chain [1] done processing
#  63%|██████▎   | 12/19 [00:43<00:04,  1.49it/s]13:42:57 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:57 - cmdstanpy - INFO - Chain [1] done processing
#  68%|██████▊   | 13/19 [00:44<00:03,  1.84it/s]13:42:57 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:58 - cmdstanpy - INFO - Chain [1] done processing
#  74%|███████▎  | 14/19 [00:44<00:02,  2.14it/s]13:42:58 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:58 - cmdstanpy - INFO - Chain [1] done processing
#  79%|███████▉  | 15/19 [00:44<00:01,  2.48it/s]13:42:58 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:58 - cmdstanpy - INFO - Chain [1] done processing
#  84%|████████▍ | 16/19 [00:45<00:01,  2.77it/s]13:42:58 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:58 - cmdstanpy - INFO - Chain [1] done processing
#  89%|████████▉ | 17/19 [00:45<00:00,  3.11it/s]13:42:58 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:59 - cmdstanpy - INFO - Chain [1] done processing
#  95%|█████████▍| 18/19 [00:45<00:00,  3.14it/s]13:42:59 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:59 - cmdstanpy - INFO - Chain [1] done processing
# 100%|██████████| 19/19 [00:45<00:00,  2.42s/it]
#   -> CV RMSE: 97,949 (21.30%), In-sample: 7,080 (1.54%)
#
#
# === BEST MODEL SELECTED ===
# CV RMSE: 55,800 (12.13% of mean)
# In-sample RMSE: 7,465 (1.62% of mean)
# Best params: {'yearly_seasonality': True, 'changepoint_range': 0.8, 'interval_width': 0.7, 'uncertainty_samples': 300, 'changepoint_prior_scale': 0.001, 'seasonality_prior_scale': 5.0, 'seasonality_mode': 'multiplicative', 'monthly_fourier': 3, 'n_changepoints': 10}
#
#
# === HOLDOUT EVALUATION (last 3 months) ===
# Train: 50 rows, Test: 3 rows
# 13:42:59 - cmdstanpy - INFO - Chain [1] start processing
# 13:42:59 - cmdstanpy - INFO - Chain [1] done processing
# Holdout RMSE:  30,272
# Holdout RMSE % mean:  6.58%
# Holdout MAPE:         4.91%
#
# ========== RMSE INTERPRETATION ==========
# Mean sales: 459,843.64
# Selected RMSE (holdout): 30,271.66
# Selected RMSE % of mean: 6.58%
# Interpretation: Very good accuracy - suitable for precise CRM targets.
# =========================================
#
#
# Projecting future regressor values...
# [OK] Saved forecast -> c:\Users\hafsa\OneSciptForcast\outputs\prophet_sales_forecast_results.csv
#
# [OK] Saved historical performance -> c:\Users\hafsa\OneSciptForcast\outputs\prophet_historical_performance.csv
#
# [OK] Saved plot -> c:\Users\hafsa\OneSciptForcast\outputs\prophet_optimized_forecast.png
# ============================================================
# [OK] OPTIMIZED FORECAST COMPLETE
# [OK] Target RMSE: <10% (Current: 6.58%)
# ============================================================
# [OK] Updated README metrics -> c:\Users\hafsa\OneSciptForcast\README.md
